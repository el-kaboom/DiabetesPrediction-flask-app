# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('kaggle_diabetes.csv')

# %%
df = df.rename(columns={'DiabetesPedigreeFunction':'DPF'})
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0            2      138             62             35        0  33.6  0.127
# 1            0       84             82             31      125  38.2  0.233
# 2            0      145              0              0        0  44.2  0.630
# 3            0      135             68             42      250  42.3  0.365
# 4            1      139             62             41      480  40.7  0.536
#
#    Age  Outcome
# 0   47        1
# 1   23        0
# 2   31        1
# 3   24        1
# 4   21        0

# %%
df_copy = df.copy(deep=True)
df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)
df_copy.isnull().sum()
# Out:
# Pregnancies        0
# Glucose           13
# BloodPressure     90
# SkinThickness    573
# Insulin          956
# BMI               28
# DPF                0
# Age                0
# Outcome            0
# dtype: int64

# %%
df_copy['Glucose'].fillna(df_copy['Glucose'].mean(), inplace=True)
df_copy['BloodPressure'].fillna(df_copy['BloodPressure'].mean(), inplace=True)
df_copy['SkinThickness'].fillna(df_copy['SkinThickness'].median(), inplace=True)
df_copy['Insulin'].fillna(df_copy['Insulin'].median(), inplace=True)
df_copy['BMI'].fillna(df_copy['BMI'].median(), inplace=True)
# Out:
# <ipython-input-5-c4e7c45c05e6>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy['Glucose'].fillna(df_copy['Glucose'].mean(), inplace=True)
# <ipython-input-5-c4e7c45c05e6>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy['BloodPressure'].fillna(df_copy['BloodPressure'].mean(), inplace=True)
# <ipython-input-5-c4e7c45c05e6>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy['SkinThickness'].fillna(df_copy['SkinThickness'].median(), inplace=True)
# <ipython-input-5-c4e7c45c05e6>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy['Insulin'].fillna(df_copy['Insulin'].median(), inplace=True)
# <ipython-input-5-c4e7c45c05e6>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy['BMI'].fillna(df_copy['BMI'].median(), inplace=True)

# %%
X = df.drop(columns='Outcome')
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (1600, 8), X_test size: (400, 8)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#base models
logreg = LogisticRegression()
dt = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
svm = SVC(probability=True, random_state=42)

param_grid_logreg = {
    'C': [0.01, 0.1, 1, 10],
    'penalty': ['l2'],
    'solver': ['lbfgs', 'saga']
}

param_grid_dt = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'criterion': ['gini', 'entropy']
}

param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

param_grid_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

grid_logreg = GridSearchCV(logreg, param_grid_logreg, cv=5, scoring='accuracy', verbose=1)
grid_dt = GridSearchCV(dt, param_grid_dt, cv=5, scoring='accuracy', verbose=1)
grid_rf = GridSearchCV(rf, param_grid_rf, cv=5, scoring='accuracy', verbose=1)
grid_svm = GridSearchCV(svm, param_grid_svm, cv=5, scoring='accuracy', verbose=1)

grid_logreg.fit(X_train, y_train)
grid_dt.fit(X_train, y_train)
grid_rf.fit(X_train, y_train)
grid_svm.fit(X_train, y_train)

best_logreg = grid_logreg.best_estimator_
best_dt = grid_dt.best_estimator_
best_rf = grid_rf.best_estimator_
best_svm = grid_svm.best_estimator_

print("Best Logistic Regression Parameters:", grid_logreg.best_params_)
print("Best Decision Tree Parameters:", grid_dt.best_params_)
print("Best Random Forest Parameters:", grid_rf.best_params_)
print("Best SVM Parameters:", grid_svm.best_params_)

#VotingClassifier with tuned models
voting_clf = VotingClassifier(estimators=[
    ('logreg', best_logreg),
    ('dt', best_dt),
    ('rf', best_rf),
    ('svm', best_svm)
], voting='soft')

voting_clf.fit(X_train, y_train)

y_pred = voting_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Voting Classifier Accuracy:", accuracy)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Logistic Regression Parameters: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Best Decision Tree Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2}
# Best Random Forest Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# Best SVM Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Voting Classifier Accuracy: 0.97
